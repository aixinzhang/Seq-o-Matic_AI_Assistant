# %%
import os
import json
from system.fluidics_exchange_system import FluidicSystem

# %%
pos_path = "C://"
system_path=os.getcwd()
heater_dict={'chamber1': "heatstage1", 'chamber2': "heatstage2", 'chamber3': "heatstage3"}
fluidics = FluidicSystem(system_path=system_path,pos_path=pos_path,slide_hearter_dictionary=heater_dict)
# Out:
# dictionary key
# dict_values(['heatstage1', 'heatstage2', 'heatstage3'])

# %%
fluidics.config_syringe_pump()

# %%
with open(os.path.join(system_path, "reagent_sequence_file","2_chamber_system_sequence", 'Fluidics_sequence_fill_all.json'), 'r') as r:
    Fill_ALL_SEQUENCE = json.load(r)

# %%
check=Fill_ALL_SEQUENCE[4]['source']
check
# Out:
# 1

# %%
check not in ["null", "", '','null']
# Out:
# False
